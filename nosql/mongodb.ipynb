# %%
import pymongo # this gives a security warning in some cases

# %%
db_name = 'my_mongo_db'
client = pymongo.MongoClient('mongodb://mongo:27017/') # connect to DS
version = client.server_info()["version"]
print(f"MongoDB version: {version}")
print(client.list_database_names()) # show names
if db_name in client.list_database_names(): # if data_science already exists, drop
    client.drop_database(db_name)
# Out:
# MongoDB version: 8.2.1
# ['admin', 'config', 'local', 'my_mongo_db']

# %%
db = client.my_mongo_db
db
# Out:
# Database(MongoClient(host=['mongo:27017'], document_class=dict, tz_aware=False, connect=True), 'my_mongo_db')

# %%
import datetime

hw =   {"author": "Etienne",
        "hw"    : "Word Count",
        "cmd"   : "line.lower()",
        "tags"  : ["MapReduce", "word", "count", "normalization"],
        "date"  : datetime.datetime.utcnow()}
hw
# Out:
# {'author': 'Etienne',
#  'hw': 'Word Count',
#  'cmd': 'line.lower()',
#  'tags': ['MapReduce', 'word', 'count', 'normalization'],
#  'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 574429)}

# %%
# create a collection
hws = db.hws
# delete everything from hws
db.hws.delete_many({})
# insert one and get ID
hw_id = hws.insert_one(hw).inserted_id
hw_id
# Out:
# ObjectId('6914700acbecf950c0ae34b4')

# %%
# get list of collections 
db.list_collection_names()
# Out:
# ['hws']

# %%
# find any
hws.find_one()
# Out:
# {'_id': ObjectId('6914700acbecf950c0ae34b4'),
#  'author': 'Etienne',
#  'hw': 'Word Count',
#  'cmd': 'line.lower()',
#  'tags': ['MapReduce', 'word', 'count', 'normalization'],
#  'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 574000)}

# %%
# these two lines find the same doc
r = hws.find_one( {'_id': hw_id} )
print(r)
# Out:
# {'_id': ObjectId('6914700acbecf950c0ae34b4'), 'author': 'Etienne', 'hw': 'Word Count', 'cmd': 'line.lower()', 'tags': ['MapReduce', 'word', 'count', 'normalization'], 'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 574000)}

# %%
print(hws.find_one({'tags': 'MapReduce'}))
# Out:
# {'_id': ObjectId('6914700acbecf950c0ae34b4'), 'author': 'Etienne', 'hw': 'Word Count', 'cmd': 'line.lower()', 'tags': ['MapReduce', 'word', 'count', 'normalization'], 'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 574000)}

# %%
# create a list of dictionaries
student_weekend_hws = [ {"author": "Simone",
        "hw"    : "Word Count",
        "cmd"   : "line.lower()",
        "tags"  : ["MapReduce", "word", "count", "normalization"],
        "date"  : datetime.datetime.utcnow()},
        
       {"author": "Joseph",
        "hw"     : "MongoDB",
        "hrs"    : 1,
        "cmd"    : [ "student_weekend_hws = []", "hws.insert_many(student_weekend_hws)" ],
        "tags"   : ["big", "data", "nosql"],
        "date"   : datetime.datetime.utcnow()} ]

# %%
hws.insert_many(student_weekend_hws).inserted_ids
# Out:
# [ObjectId('6914700acbecf950c0ae34b5'), ObjectId('6914700acbecf950c0ae34b6')]

# %%
for hw in hws.find():
    print(hw['author'], hw['date'])
    
print(hws.count_documents({})) # notice the empty filter
# Out:
# Etienne 2025-11-12 11:31:22.574000
# Simone 2025-11-12 11:31:22.645000
# Joseph 2025-11-12 11:31:22.645000
# 3

# %%
# you need to change the following date time for proper querying (depending on
# when the above was run)
d = datetime.datetime(2021, 7, 26, 12, 48, 26, 0)
for h in hws.find({"date": {"$gt": d}}).sort("author"):
    print(h)
# Out:
# {'_id': ObjectId('6914700acbecf950c0ae34b4'), 'author': 'Etienne', 'hw': 'Word Count', 'cmd': 'line.lower()', 'tags': ['MapReduce', 'word', 'count', 'normalization'], 'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 574000)}
# {'_id': ObjectId('6914700acbecf950c0ae34b6'), 'author': 'Joseph', 'hw': 'MongoDB', 'hrs': 1, 'cmd': ['student_weekend_hws = []', 'hws.insert_many(student_weekend_hws)'], 'tags': ['big', 'data', 'nosql'], 'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 645000)}
# {'_id': ObjectId('6914700acbecf950c0ae34b5'), 'author': 'Simone', 'hw': 'Word Count', 'cmd': 'line.lower()', 'tags': ['MapReduce', 'word', 'count', 'normalization'], 'date': datetime.datetime(2025, 11, 12, 11, 31, 22, 645000)}

# %%
# can use remove in the same way
print(db.hws.count_documents({}))
id = db.hws.find_one()['_id']
db.hws.delete_one({'_id': id})
print(db.hws.count_documents({}))
# Out:
# 3
# 2

# %%
# create index information
db.profiles.delete_many({})
result = db.profiles.create_index([('user_id', pymongo.ASCENDING)], unique=True)
list(db.profiles.index_information())
# Out:
# ['_id_', 'user_id_1']

# %%
user_profiles = [ {'user_id': 1, 'name': 'Brandon'},
                  {'user_id': 2, 'name': 'Luke'},
                  {'user_id': 3, 'name': 'Ivan'}]
result = db.profiles.insert_many(user_profiles)

# %%
db.profiles.count_documents({})
# Out:
# 3

# %%
new_profile = {'user_id': 4, 'name': 'Chris'}
duplicate_profile = {'user_id': 1, 'name': 'Michael'}
result = db.profiles.insert_one(new_profile)  # This is fine.
result = db.profiles.insert_one(duplicate_profile) # this creates error
# Out:
# ---------------------------------------------------------------------------
# DuplicateKeyError                         Traceback (most recent call last)
# Cell In[18], line 4
#       2 duplicate_profile = {'user_id': 1, 'name': 'Michael'}
#       3 result = db.profiles.insert_one(new_profile)  # This is fine.
# ----> 4 result = db.profiles.insert_one(duplicate_profile) # this creates error
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:891, in Collection.insert_one(self, document, bypass_document_validation, session, comment)
#     887     document["_id"] = ObjectId()  # type: ignore[index]
#     889 write_concern = self._write_concern_for(session)
#     890 return InsertOneResult(
# --> 891     self._insert_one(
#     892         document,
#     893         ordered=True,
#     894         write_concern=write_concern,
#     895         op_id=None,
#     896         bypass_doc_val=bypass_document_validation,
#     897         session=session,
#     898         comment=comment,
#     899     ),
#     900     write_concern.acknowledged,
#     901 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:831, in Collection._insert_one(self, doc, ordered, write_concern, op_id, bypass_doc_val, session, comment)
#     819     result = conn.command(
#     820         self._database.name,
#     821         command,
#    (...)
#     826         retryable_write=retryable_write,
#     827     )
#     829     _check_write_command_response(result)
# --> 831 self._database.client._retryable_write(
#     832     acknowledged, _insert_command, session, operation=_Op.INSERT
#     833 )
#     835 if not isinstance(doc, RawBSONDocument):
#     836     return doc.get("_id")
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2082, in MongoClient._retryable_write(self, retryable, func, session, operation, bulk, operation_id)
#    2068 """Execute an operation with consecutive retries if possible
#    2069
#    2070 Returns func()'s return value on success. On error retries the same
#    (...)
#    2079 :param bulk: bulk abstraction to execute operations in bulk, defaults to None
#    2080 """
#    2081 with self._tmp_session(session) as s:
# -> 2082     return self._retry_with_session(retryable, func, s, bulk, operation, operation_id)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:1968, in MongoClient._retry_with_session(self, retryable, func, session, bulk, operation, operation_id)
#    1963 # Ensure that the options supports retry_writes and there is a valid session not in
#    1964 # transaction, otherwise, we will not support retry behavior for this txn.
#    1965 retryable = bool(
#    1966     retryable and self.options.retry_writes and session and not session.in_transaction
#    1967 )
# -> 1968 return self._retry_internal(
#    1969     func=func,
#    1970     session=session,
#    1971     bulk=bulk,
#    1972     operation=operation,
#    1973     retryable=retryable,
#    1974     operation_id=operation_id,
#    1975 )
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/_csot.py:125, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     123         with _TimeoutContext(timeout):
#     124             return func(self, *args, **kwargs)
# --> 125 return func(self, *args, **kwargs)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2014, in MongoClient._retry_internal(self, func, session, bulk, operation, is_read, address, read_pref, retryable, operation_id)
#    1977 @_csot.apply
#    1978 def _retry_internal(
#    1979     self,
#    (...)
#    1988     operation_id: Optional[int] = None,
#    1989 ) -> T:
#    1990     """Internal retryable helper for all client transactions.
#    1991
#    1992     :param func: Callback function we want to retry
#    (...)
#    2001     :return: Output of the calling func()
#    2002     """
#    2003     return _ClientConnectionRetryable(
#    2004         mongo_client=self,
#    2005         func=func,
#    2006         bulk=bulk,
#    2007         operation=operation,
#    2008         is_read=is_read,
#    2009         session=session,
#    2010         read_pref=read_pref,
#    2011         address=address,
#    2012         retryable=retryable,
#    2013         operation_id=operation_id,
# -> 2014     ).run()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2765, in _ClientConnectionRetryable.run(self)
#    2763 self._check_last_error(check_csot=True)
#    2764 try:
# -> 2765     return self._read() if self._is_read else self._write()
#    2766 except ServerSelectionTimeoutError:
#    2767     # The application may think the write was never attempted
#    2768     # if we raise ServerSelectionTimeoutError on the retry
#    2769     # attempt. Raise the original exception instead.
#    2770     self._check_last_error()
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/mongo_client.py:2897, in _ClientConnectionRetryable._write(self)
#    2889         if self._retrying:
#    2890             _debug_log(
#    2891                 _COMMAND_LOGGER,
#    2892                 message=f"Retrying write attempt number {self._attempt_number}",
#    (...)
#    2895                 operationId=self._operation_id,
#    2896             )
# -> 2897         return self._func(self._session, conn, self._retryable)  # type: ignore
#    2898 except PyMongoError as exc:
#    2899     if not self._retryable:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/synchronous/collection.py:829, in Collection._insert_one.<locals>._insert_command(session, conn, retryable_write)
#     817     command["bypassDocumentValidation"] = bypass_doc_val
#     819 result = conn.command(
#     820     self._database.name,
#     821     command,
#    (...)
#     826     retryable_write=retryable_write,
#     827 )
# --> 829 _check_write_command_response(result)
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/helpers_shared.py:322, in _check_write_command_response(result)
#     320 write_errors = result.get("writeErrors")
#     321 if write_errors:
# --> 322     _raise_last_write_error(write_errors)
#     324 wce = _get_wce_doc(result)
#     325 if wce:
#
# File /opt/conda/lib/python3.11/site-packages/pymongo/helpers_shared.py:292, in _raise_last_write_error(write_errors)
#     290 error = write_errors[-1]
#     291 if error.get("code") == 11000:
# --> 292     raise DuplicateKeyError(error.get("errmsg"), 11000, error)
#     293 raise WriteError(error.get("errmsg"), error.get("code"), error)
#
# DuplicateKeyError: E11000 duplicate key error collection: my_mongo_db.profiles index: user_id_1 dup key: { user_id: 1 }, full error: {'index': 0, 'code': 11000, 'errmsg': 'E11000 duplicate key error collection: my_mongo_db.profiles index: user_id_1 dup key: { user_id: 1 }', 'keyPattern': {'user_id': 1}, 'keyValue': {'user_id': 1}}

# %%
# see all user profiles
for p in db.profiles.find():
    print(p)
# Out:
# {'_id': ObjectId('6914700acbecf950c0ae34b7'), 'user_id': 1, 'name': 'Brandon'}
# {'_id': ObjectId('6914700acbecf950c0ae34b8'), 'user_id': 2, 'name': 'Luke'}
# {'_id': ObjectId('6914700acbecf950c0ae34b9'), 'user_id': 3, 'name': 'Ivan'}
# {'_id': ObjectId('6914700acbecf950c0ae34ba'), 'user_id': 4, 'name': 'Chris'}

# %%
print([ x for x in db.profiles.find({"name": "Ivan"}) ])
# Out:
# [{'_id': ObjectId('6914700acbecf950c0ae34b9'), 'user_id': 3, 'name': 'Ivan'}]
